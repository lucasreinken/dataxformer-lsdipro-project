# %%
l = 3000
with open("../data/tables.json", "r") as infile, open(f"../data/tables_{l}.json", "w") as outfile:
    for i, line in enumerate(infile):
        if i >= l:
            break
        outfile.write(line)

# %%
import pandas as pd
import numpy as np 
import torch 
import matplotlib.pyplot as plt 
import collections
import nltk 
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import string
nltk.download('punkt')
nltk.download('punkt_tab')
from nltk import ngrams
import copy
from collections import defaultdict
from functools import cache
import cProfile
import pstats
import time
from tabulate import tabulate
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
# Utility functions
def get_clock_time_in_milli_sec():
    return int(time.time() * 1000)

def print_time(milli_sec):
    hours, remainder = divmod(milli_sec, 1000 * 60 * 60)
    minutes, remainder = divmod(remainder, 1000 * 60)
    seconds, milli_seconds = divmod(remainder, 1000)
    components = []
    if hours:
        components.append(f"{hours}h")
    if minutes:
        components.append(f"{minutes}m")
    if seconds:
        components.append(f"{seconds}s")
    if milli_seconds:
        components.append(f"{milli_seconds}ms")
    print(f"{milli_sec}[{':'.join(components)}]")

# %%
def create_table_list(dfs):
    return [[[cell.get('text', '') for cell in row] for row in table_data] for table_data in dfs['tableData']]

# %%
@cache
def process_words(text:str)->list: 
    sentence = text.lower().translate(str.maketrans("", "", string.punctuation))
    words = word_tokenize(sentence)
    return words

# %%
ps = PorterStemmer()

# %%
@cache
def stem_cached(word):
    return ps.stem(word)

# %%
def create_projections(table_list,
                       start_table_index,
                       projections,
                       stemmer, 
                       stop_words: list = None, 
                       min_word_len = 0, 
                       create_ngrams:bool = False, 
                       ngrams_size:int = 2
                       ) -> dict: 

    ps = stemmer
    
    if stop_words: 
        stemmed_stopwords = {ps.stem_cached(w) for w in stop_words}
    else:
        stemmed_stopwords = set()

    for table_index, table in enumerate(table_list): 
        for row_index, row in enumerate(table): 
            for column_index, cell in enumerate(row): 

                words = process_words(cell)

                if create_ngrams: 
                    ngram_stem_set = set()

                for word in words: 
                    stemmed_word = stem_cached(word)
                        
                    if stemmed_word not in stemmed_stopwords and len(stemmed_word) >= min_word_len: 

                        projections.setdefault(stemmed_word, set()).add((table_index, row_index, column_index))

                        if create_ngrams: 
                            ngram_stem_set.update(stemmed_word)
                
                if create_ngrams: 
                    created_ngrams = ngrams(ngram_stem_set, ngrams_size)
                    for created_ngram in created_ngrams: 
                        projections.setdefault(created_ngram, set()).add((table_index, row_index, column_index))
    
    return projections

# %%
def create_tables_df(table_chunk, start_table_index, tables_df): 

    new_tables_df = pd.DataFrame({
        "id": range(start_table_index, start_table_index + len(table_chunk)),
        "pgTitle": table_chunk.get('pgTitle', ''),
        "sectionTitle": table_chunk.get('sectionTitle', ''),
        "tableCaption": table_chunk.get('tableCaption', ''),
        "weight": [0.5] * len(table_chunk)
    })

    if not tables_df.empty:
        tables_df = pd.concat([tables_df, new_tables_df], ignore_index=True)
    else:
        tables_df = new_tables_df

    return tables_df

# %%
def cleaner(value, create_ngrams:bool = False, ngram_size:int = 2) -> list: ####Umbenennen 
    """
    Returns the tokenized and stemed version of a Value
    """
    words = process_words(value)

    stemmed_words = [stem_cached(word) for word in words]

    if create_ngrams: 
        created_ngrams = ngrams(stemmed_words, ngram_size)
        stemmed_words.extend(list(created_ngrams))
        
    return stemmed_words

# %%
def indexing(cleaned_values:list, projections:dict)->dict: 
    """
    Return a dict of all the Examples found in the projections
    In: 
        Cleaned_Values: A List of all the Stemped Versions of one Example given
        Projections: A Dict of Projections of all given Tables
    Out: 
        Index_Dict: A dict of all the positions where the Example was found
                    Form: Key: (Table_ID, Row_ID) -> Value: (Col_ID)
    """
    index_dict = dict() 
    
    for value in cleaned_values: 
        value_index = projections.get(value, None)

        if value_index: 
            for index_pair in value_index: 
                table_id, row_id, col_id = index_pair 
                index_dict.setdefault((table_id, row_id), set()).add((col_id))
    
    return index_dict

# %%
def compareit(dictx:dict, dicty:dict, sub_key_mode:bool = False)-> list: 
    """
    Compairs two Dicts with eachother and return a Dict of Intersections between Dicts 
    In: 
        Dictx: Dict of the Form Key: (Table_ID, Row_ID) -> Value: (Row_ID(s))
        Dicty: Dict of the Form Key: (Table_ID, Row_ID) -> Value: (Row_ID(s))
        Sub_Key_Mode: Bool that assures that the output dict is in a Form that another instance of 
                      Compareit could use it
    Out: 
        Possible_Tables_Dict/ Subkey_Dict: A Dict of all Intersections between Dictx and Dicty
                                           In the Form of Dictx/ Dicty if Sub_Key_Mode == True 
    """

    if not sub_key_mode: 
        possible_tables_dict = dict()
    else: 
        subkey_dict = dict()
    intersecting_keys = set(dictx) & set(dicty)
    for key in intersecting_keys: 
        table_id, row_id = key
        for x_col_id in dictx[key]: 
            for y_col_id in dicty[key]: 
                if not sub_key_mode: 
                    possible_tables_dict.setdefault(table_id, set()).add((row_id, (x_col_id, y_col_id)))
                    
                else: 
                    subkey_dict.setdefault(key, set()).add((x_col_id, y_col_id))
    if not sub_key_mode: 
        return possible_tables_dict
    else: 
        return subkey_dict

# %%
def querry_thunel(example_pairs:list, projections:dict, tau:int=1):
    """
    Perfoms the complete Querrying Web Tables Operation. 
    In: 
        Example_Pairs: A List of the Semmantic Mapping 
        Projections: A Dict of Projections of all given Tables
        Tau: An Int which indicates how many Example_pairs must be in a Table to count as relevant
    Out: 
        Tables: A Dict of all relevant Tables 
                Form: Key: Table_ID -> Value: (Row_ID, (XColumn_ID, YColumn_ID))
    """
    
    if len(example_pairs) < tau: 
        raise ValueError(f"The Cardinality of given Example_Pairs {len(example_pairs)} must be greater or qual then Tau: {tau}!")
    

    possible_tables = dict()

    for tup in example_pairs: 
        list_of_keys = list()
        for val in tup: 
            
            if isinstance(val, tuple): 
                list_of_subkeys = list()
                for sub_key in val: 
                    cleaned_sub_key = cleaner(sub_key)
                    index_of_sub_key = indexing(cleaned_sub_key, projections)
                    list_of_subkeys.append(index_of_sub_key)
                key_val = compareit(*list_of_subkeys, sub_key_mode=True)
                
            
            else: 
                cleaned_key = cleaner(val)
                index_of_key = indexing(cleaned_key, projections)
                key_val = index_of_key
            
            list_of_keys.append(key_val)
        
        

        compared_things = compareit(*list_of_keys)
        possible_tables.update(compared_things)

    tables = dict()
    for key in possible_tables: 
        if len(possible_tables[key]) >= tau: 
            tables[key] = possible_tables[key]

    return tables

# %%
def iter_json(path, csize):
    iter_chunk = pd.read_json(path, lines=True, chunksize=csize)
    for chunk in iter_chunk:
        yield chunk

# %%
if __name__ == "__main__":

    csize = 300
    path = "../data/tables_1000.json"

    start_table_index = 0

    projections = dict()
    tables_df = pd.DataFrame()

    c = get_clock_time_in_milli_sec()

    profiler = cProfile.Profile()
    profiler.enable()

    for table_chunk in iter_json(path, csize):
        
        table_list = create_table_list(table_chunk)

        projections = create_projections(table_list, start_table_index, projections, ps, create_ngrams=True, min_word_len=3)

        tables_df = create_tables_df(table_chunk, start_table_index, tables_df)

        start_table_index += csize

    print(tabulate(tables_df, headers='keys', tablefmt='psql'))

    c = get_clock_time_in_milli_sec() - c

    print("Time=", end="")
    print_time(c)
    print()

    profiler.disable()
    stats = pstats.Stats(profiler)
    stats.strip_dirs()
    stats.sort_stats("time")
    stats.print_stats()

    indexing_example = [('1929', 'Robert Crawford')]
    multikey_indexing_example = [(('1929', 'Robert Crawford'), 'Ulster Unionist')]
    tau = 1

    final_list_single_key = querry_thunel(indexing_example, projections, tau)
    final_list_muli_key = querry_thunel(multikey_indexing_example, projections, tau)

    print(final_list_single_key)
    print(final_list_muli_key)
# Out:
# +-----+------+------------------------------------------------------------------------------+--------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+----------+
# |     |   id | pgTitle                                                                      | sectionTitle                                                                         | tableCaption                                                                                             |   weight |
# |-----+------+------------------------------------------------------------------------------+--------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+----------|
# |   0 |    0 | Mid Antrim (Northern Ireland Parliament constituency)                        | Members of Parliament                                                                | Members of Parliament                                                                                    |      0.5 |
# |   1 |    1 | Römer (crater)                                                               | Satellite craters                                                                    | Satellite craters                                                                                        |      0.5 |
# |   2 |    2 | Whispermoon                                                                  |                                                                                      | Track listing                                                                                            |      0.5 |
# |   3 |    3 | Khalsa Diwan Society Vancouver                                               | First executive committee                                                            | First executive committee                                                                                |      0.5 |
# |   4 |    4 | Julien Leparoux                                                              | Year-end charts                                                                      | Year-end charts                                                                                          |      0.5 |
# |   5 |    5 | Barton Academy (Vermont)                                                     | Principals                                                                           | Principals                                                                                               |      0.5 |
# |   6 |    6 | Real Voice                                                                   | Charts                                                                               | Charts                                                                                                   |      0.5 |
# |   7 |    7 | Acrimony                                                                     | Albums                                                                               | Albums                                                                                                   |      0.5 |
# |   8 |    8 | Acrimony                                                                     | EPs and Singles                                                                      | EPs and Singles                                                                                          |      0.5 |
# |   9 |    9 | James Fiennes, 1st Baron Saye and Sele                                       | Ancestry                                                                             | Ancestry                                                                                                 |      0.5 |
# |  10 |   10 | Dettmar Cramer                                                               | Career statistics                                                                    | Career statistics                                                                                        |      0.5 |
# |  11 |   11 | Dettmar Cramer                                                               | External links                                                                       | External links                                                                                           |      0.5 |
# |  12 |   12 | Katha, Burma                                                                 | Climate                                                                              | Climate                                                                                                  |      0.5 |
# |  13 |   13 | Gone till November                                                           | Charts                                                                               | Charts                                                                                                   |      0.5 |
# |  14 |   14 | Mikazuki (song)                                                              | Charts                                                                               | Charts                                                                                                   |      0.5 |
# |  15 |   15 | Sabine (crater)                                                              | Satellite craters                                                                    | Satellite craters                                                                                        |      0.5 |
# |  16 |   16 | Secchi (lunar crater)                                                        | Satellite craters                                                                    | Satellite craters                                                                                        |      0.5 |
# |  17 |   17 | Silberschlag (crater)                                                        | Satellite craters                                                                    | Satellite craters                                                                                        |      0.5 |
# |  18 |   18 | The Valley (London)                                                          | Average attendances                                                                  | Average attendances                                                                                      |      0.5 |
# |  19 |   19 | The Valley (London)                                                          | Average attendances                                                                  | Average attendances                                                                                      |      0.5 |
# |  20 |   20 | The Valley (London)                                                          | Average attendances                                                                  | Average attendances                                                                                      |      0.5 |
# |  21 |   21 | Sosigenes (crater)                                                           | Satellite craters                                                                    | Satellite craters                                                                                        |      0.5 |
# |  22 |   22 | Tu Ángel de la Guarda                                                        | Track listing                                                                        | Track listing                                                                                            |      0.5 |
# |  23 |   23 | 2006 SEC Men's Basketball Tournament                                         | Final SEC Regular Season Standings                                                   | Final SEC Regular Season Standings                                                                       |      0.5 |
# |  24 |   24 | 2006 SEC Men's Basketball Tournament                                         | Final SEC Regular Season Standings                                                   | Final SEC Regular Season Standings                                                                       |      0.5 |
# |  25 |   25 | RAF Lindholme                                                                | Station commanders                                                                   | Station commanders                                                                                       |      0.5 |
# |  26 |   26 | Manitoba general election, 1977                                              | Results                                                                              | Results                                                                                                  |      0.5 |
# |  27 |   27 | Manitoba general election, 1977                                              | Riding results                                                                       | Riding results                                                                                           |      0.5 |
# |  28 |   28 | Manitoba general election, 1977                                              | Riding results                                                                       | Riding results                                                                                           |      0.5 |
# |  29 |   29 | Stevinus (crater)                                                            | Satellite craters                                                                    | Satellite craters                                                                                        |      0.5 |
# |  30 |   30 | Strabo (crater)                                                              | Satellite craters                                                                    | Satellite craters                                                                                        |      0.5 |
# |  31 |   31 | Sulpicius Gallus (crater)                                                    | Satellite craters                                                                    | Satellite craters                                                                                        |      0.5 |
# |  32 |   32 | Phono-semantic matching                                                      | Arabic                                                                               | Arabic                                                                                                   |      0.5 |
# |  33 |   33 | Scott LeDoux                                                                 | Professional boxing record                                                           | Professional boxing record                                                                               |      0.5 |
# |  34 |   34 | Tacquet (crater)                                                             | Satellite craters                                                                    | Satellite craters                                                                                        |      0.5 |
# |  35 |   35 | Frederick William II, Duke of Saxe-Altenburg                                 |                                                                                      | nan                                                                                                      |      0.5 |
# |  36 |   36 | Reamer                                                                       | Tool materials                                                                       | Tool materials                                                                                           |      0.5 |
# |  37 |   37 | Reamer                                                                       | Lubrication                                                                          | Lubrication                                                                                              |      0.5 |
# |  38 |   38 | Thales (crater)                                                              | Satellite craters                                                                    | Satellite craters                                                                                        |      0.5 |
# |  39 |   39 | Torricelli (crater)                                                          | Satellite craters                                                                    | Satellite craters                                                                                        |      0.5 |
# |  40 |   40 | Bodø Station                                                                 | References                                                                           | References                                                                                               |      0.5 |
# |  41 |   41 | Hypnotic Brass Ensemble                                                      | Discography                                                                          | Discography                                                                                              |      0.5 |
# |  42 |   42 | Tsiolkovskiy (crater)                                                        | Satellite craters                                                                    | Satellite craters                                                                                        |      0.5 |
# |  43 |   43 | Robert Clark Corrente                                                        | External links                                                                       | External links                                                                                           |      0.5 |
# |  44 |   44 | Robert Baden-Powell, 3rd Baron Baden-Powell                                  | References                                                                           | References                                                                                               |      0.5 |
# |  45 |   45 | Vehicle registration plates of Australia                                     | Summary of current General Series standard issue plates                              | Summary of current General Series standard issue plates                                                  |      0.5 |
# |  46 |   46 | Vehicle registration plates of Australia                                     | Summary of current trailer and caravan standard issue plates                         | Summary of current trailer and caravan standard issue plates                                             |      0.5 |
# |  47 |   47 | Vehicle registration plates of Australia                                     | Summary of current motorcycle standard issue plates                                  | Summary of current motorcycle standard issue plates                                                      |      0.5 |
# |  48 |   48 | Vehicle registration plates of Australia                                     | Special purpose vehicles                                                             | Special purpose vehicles                                                                                 |      0.5 |
# |  49 |   49 | Vitruvius (crater)                                                           | Satellite craters                                                                    | Satellite craters                                                                                        |      0.5 |
# |
0.000    0.000    0.000    0.000 __init__.py:225(compile)
#        16    0.000    0.000    0.000    0.000 construction.py:687(_sanitize_non_ordered)
#        12    0.000    0.000    0.000    0.000 locale.py:479(_parse_localename)
#        16    0.000    0.000    0.000    0.000 managers.py:2242(<listcomp>)
#         8    0.000    0.000    0.000    0.000 generic.py:1383(<genexpr>)
#        12    0.000    0.000    0.000    0.000 base.py:1751(_get_names)
#        16    0.000    0.000    0.000    0.000 datetimes.py:156(should_cache)
#         3    0.000    0.000    0.000    0.000 concat.py:478(_get_ndims)
#         4    0.000    0.000    0.000    0.000 series.py:581(_constructor_from_mgr)
#         1    0.000    0.000    0.001    0.001 _json.py:912(_get_data_from_filepath)
#         5    0.000    0.000    0.000    0.000 <frozen ntpath>:319(expanduser)
#         9    0.000    0.000    0.000    0.000 missing.py:564(_array_equivalent_object)
#         4    0.000    0.000    0.000    0.000 common.py:1066(is_numeric_dtype)
#        12    0.000    0.000    0.000    0.000 _parser.py:189(__next__)
#        12    0.000    0.000    0.000    0.000 _strptime.py:26(_getlang)
#         3    0.000    0.000    0.000    0.000 frozen.py:73(__getitem__)
#        11    0.000    0.000    0.000    0.000 generic.py:2073(<genexpr>)
#        13    0.000    0.000    0.000    0.000 base.py:791(is_)
#         8    0.000    0.000    0.000    0.000 base.py:3752(_convert_can_do_setop)
#        27    0.000    0.000    0.000    0.000 concat.py:584(<genexpr>)
#         3    0.000    0.000    0.000    0.000 api.py:106(_get_distinct_objs)
#         4    0.000    0.000    0.000    0.000 managers.py:1812(from_blocks)
#         1    0.000    0.000    0.001    0.001 _json.py:500(read_json)
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#        68    0.000    0.000    0.000    0.000 base.py:6612(_maybe_cast_indexer)
#        15    0.000    0.000    0.000    0.000 managers.py:896(__init__)
#         4    0.000    0.000    0.005    0.001 construction.py:1006(convert_object_array)
#         4    0.000    0.000    0.000    0.000 generic.py:2015(empty)
#         4    0.000    0.000    0.000    0.000 dataclasses.py:1256(is_dataclass)
#         8    0.000    0.000    0.000    0.000 expressions.py:67(_evaluate_standard)
#         3    0.000    0.000    0.000    0.000 concat.py:565(<listcomp>)
#         3    0.000    0.000    0.000    0.000 managers.py:1683(<listcomp>)
#        26    0.000    0.000    0.000    0.000 common.py:123(<lambda>)
#         3    0.000    0.000    0.000    0.000 concat.py:713(_get_concat_axis)
#         3    0.000    0.000    0.001    0.000 concat.py:698(<listcomp>)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#        12    0.000    0.000    0.000    0.000 range.py:554(equals)
#         1    0.000    0.000    0.000    0.000 __init__.py:2182(<listcomp>)
#         3    0.000    0.000    0.000    0.000 base.py:1243(copy)
#        48    0.000    0.000    0.000    0.000 range.py:377(dtype)
#         9    0.000    0.000    0.000    0.000 blocks.py:2245(get_values)
#         4    0.000    0.000    0.000    0.000 construction.py:765(_try_cast)
#         3    0.000    0.000    0.001    0.000 concat.py:695(new_axes)
#         4    0.000    0.000    0.000    0.000 common.py:233(stringify_path)
#         1    0.000    0.000    0.000    0.000 readers.py:518(validate_integer)
#        26    0.000    0.000    0.000    0.000 common.py:121(classes)
#        48    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#        16    0.000    0.000    0.000    0.000 base.py:539(<genexpr>)
#         8    0.000    0.000    0.000    0.000 base.py:3180(_get_reconciled_name_object)
#         1    0.000    0.000    0.000    0.000 __init__.py:1022(_is_multiline)
#         1    0.000    0.000    0.000    0.000 iostream.py:258(schedule)
#        52    0.000    0.000    0.000    0.000 _json.py:1401(<lambda>)
#         3    0.000    0.000    0.000    0.000 concat.py:202(_maybe_reindex_columns_na_proxy)
#         3    0.000    0.000    0.000    0.000 api.py:270(<listcomp>)
#        41    0.000    0.000    0.000    0.000 multiarray.py:153(concatenate)
#         6    0.000    0.000    0.000    0.000 __init__.py:1243(<listcomp>)
#        12    0.000    0.000    0.000    0.000 managers.py:920(<genexpr>)
#         4    0.000    0.000    0.001    0.000 arraylike.py:38(__eq__)
#         8    0.000    0.000    0.000    0.000 expressions.py:76(_can_use_numexpr)
#         4    0.000    0.000    0.000    0.000 construction.py:668(range_to_ndarray)
#         4    0.000    0.000    0.000    0.000 construction.py:950(_validate_or_indexify_columns)
#         7    0.000    0.000    0.000    0.000 iostream.py:519(_is_master_process)
#         3    0.000    0.000    0.000    0.000 base.py:7645(<listcomp>)
#         1    0.000    0.000    0.000    0.000 1428111118.py:5(print_time)
#        12    0.000    0.000    0.000    0.000 _parser.py:203(isword)
#         7    0.000    0.000    0.000    0.000 api.py:344(<setcomp>)
#         5    0.000    0.000    0.000    0.000 common.py:173(_expand_user)
#         3    0.000    0.000    0.001    0.000 concat.py:703(_get_comb_axis)
#         4    0.000    0.000    0.000    0.000 base.py:459(_engine_type)
#         4    0.000    0.000    0.001    0.000 arraylike.py:54(__gt__)
#         4    0.000    0.000    0.000    0.000 generic.py:1381(_indexed_same)
#         8    0.000    0.000    0.000    0.000 dispatch.py:17(should_extension_dispatch)
#         6    0.000    0.000    0.000    0.000 generic.py:568(_get_block_manager_axis)
#         4    0.000    0.000    0.000    0.000 _parser.py:322(weekday)
#         9    0.000    0.000    0.000    0.000 concat.py:167(<listcomp>)
#         3    0.000    0.000    0.000    0.000 __init__.py:2300(_build_line)
#         4    0.000    0.000    0.000    0.000 _parser.py:329(month)
#         3    0.000    0.000    0.000    0.000 concat.py:543(_get_sample_object)
#         3    0.000    0.000    0.000    0.000 frame.py:641(_constructor_from_mgr)
#         9    0.000    0.000    0.000    0.000 generic.py:6182(<genexpr>)
#         3    0.000    0.000    0.001    0.000 api.py:72(get_objs_combined_axis)
#        17    0.000    0.000    0.000    0.000 blocks.py:1003(shape)
#        12    0.000    0.000    0.000    0.000 frame.py:949(axes)
#         6    0.000    0.000    0.000    0.000 base.py:7647(<genexpr>)
#         4    0.000    0.000    0.000    0.000 api.py:281(<listcomp>)
#         3    0.000    0.000    0.000    0.000 base.py:366(ensure_np_dtype)
#         3    0.000    0.000    0.000    0.000 concat.py:747(<listcomp>)
#         2    0.000    0.000    0.000    0.000 parse.py:119(_coerce_args)
#         6    0.000    0.000    0.000    0.000 frame.py:966(shape)
#         4    0.000    0.000    0.000    0.000 nanops.py:543(nanall)
#         2    0.000    0.000    0.000    0.000 common.py:145(is_url)
#         2    0.000    0.000    0.000    0.000 common.py:277(is_fsspec_url)
#         6    0.000    0.000    0.000    0.000 {pandas._libs.lib.dtypes_all_equal}
#         4    0.000    0.000    0.000    0.000 common.py:514(is_string_or_object_np_dtype)
#        18    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_object}
#         3    0.000    0.000    0.000    0.000 base.py:773(_view)
#        16    0.000    0.000    0.000    0.000 enum.py:1249(value)
#        12    0.000    0.000    0.000    0.000 cast.py:1430(<genexpr>)
#         2    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#        18    0.000    0.000    0.000    0.000 concat.py:351(__init__)
#         4    0.000    0.000    0.000    0.000 _parser.py:342(ampm)
#         1    0.000    0.000    0.000    0.000 common.py:121(close)
#         8    0.000    0.000    0.000    0.000 construction.py:916(<genexpr>)
#         7    0.000    0.000    0.000    0.000 iostream.py:546(_schedule_flush)
#         3    0.000    0.000    0.000    0.000 concat.py:303(<listcomp>)
#         4    0.000    0.000    0.000    0.000 common.py:1025(needs_i8_conversion)
#         6    0.000    0.000    0.000    0.000 api.py:311(<genexpr>)
#         1    0.000    0.000    0.000    0.000 __init__.py:1034(_choose_width_fn)
#        16    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 common.py:131(<lambda>)
#         1    0.000    0.000    0.000    0.000 1428111118.py:2(get_clock_time_in_milli_sec)
#         4    0.000    0.000    0.000    0.000 inference.py:306(is_named_tuple)
#         1    0.000    0.000    0.000    0.000 __init__.py:2167(<listcomp>)
#         4    0.000    0.000    0.000    0.000 _validators.py:226(validate_bool_kwarg)
#        12    0.000    0.000    0.000    0.000 cast.py:1446(<genexpr>)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:309(__init__)
#         4    0.000    0.000    0.000    0.000 _parser.py:208(isnum)
#         8    0.000    0.000    0.000    0.000 base.py:3746(_assert_can_do_setop)
#         3    0.000    0.000    0.000    0.000 api.py:102(<listcomp>)
#         3    0.000    0.000    0.000    0.000 __init__.py:2312(_append_line)
#         1    0.000    0.000    0.000    0.000 __init__.py:173(search)
#         1    0.000    0.000    0.000    0.000 __init__.py:2220(_expand_iterable)
#         4    0.000    0.000    0.000    0.000 _parser.py:319(jump)
#         3    0.000    0.000    0.000    0.000 inference.py:105(is_file_like)
#        12    0.000    0.000    0.000    0.000 generic.py:659(ndim)
#         6    0.000    0.000    0.000    0.000 generic.py:6177(<genexpr>)
#         3    0.000    0.000    0.000    0.000 __init__.py:2308(<listcomp>)
#         2    0.000    0.000    0.000    0.000 <frozen _collections_abc>:78(_check_methods)
#         3    0.000    0.000    0.001    0.000 frame.py:12207(values)
#        16    0.000    0.000    0.000    0.000 {method 'read' of '_io.StringIO' objects}
#        16    0.000    0.000    0.000    0.000 fromnumeric.py:1021(_argsort_dispatcher)
#         3    0.000    0.000    0.000    0.000 base.py:347(interleaved_dtype)
#        20    0.000    0.000    0.000    0.000 series.py:1381(_clear_item_cache)
#        12    0.000    0.000    0.000    0.000 {method 'isalpha' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:1185(is_alive)
#         4    0.000    0.000    0.000    0.000 _parser.py:213(isspace)
#         9    0.000    0.000    0.000    0.000 concat.py:750(<genexpr>)
#        12    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 base.py:7646(<listcomp>)
#         1    0.000    0.000    0.000    0.000 __init__.py:2203(_expand_numparse)
#         1    0.000    0.000    0.000    0.000 <frozen genericpath>:16(exists)
#         3    0.000    0.000    0.000    0.000 concat.py:689(_get_result_dim)
#         3    0.000    0.000    0.000    0.000 base.py:782(_rename)
#         1    0.000    0.000    0.000    0.000 __init__.py:2161(<listcomp>)
#         6    0.000    0.000    0.000    0.000 cast.py:1439(<genexpr>)
#         8    0.000    0.000    0.000    0.000 base.py:974(dtype)
#         1    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup}
#        16    0.000    0.000    0.000    0.000 base.py:363(ndim)
#         1    0.000    0.000    0.000    0.000 threading.py:1118(_wait_for_tstate_lock)
#         4    0.000    0.000    0.000    0.000 range.py:281(start)
#         1    0.000    0.000    0.000    0.000 common.py:1141(file_exists)
#         7    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#        16    0.000    0.000    0.000    0.000 shape_base.py:77(_atleast_2d_dispatcher)
#         3    0.000    0.000    0.000    0.000 {built-in method fromkeys}
#         8    0.000    0.000    0.000    0.000 base.py:3191(_validate_sort_keyword)
#         6    0.000    0.000    0.000    0.000 cast.py:1441(<genexpr>)
#         9    0.000    0.000    0.000    0.000 common.py:175(<genexpr>)
#         3    0.000    0.000    0.000    0.000 common.py:171(not_none)
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         8    0.000    0.000    0.000    0.000 series.py:577(_constructor)
#         1    0.000    0.000    0.000    0.000 _json.py:896(_preprocess_data)
#         1    0.000    0.000    0.000    0.000 iostream.py:137(_event_pipe)
#         7    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         4    0.000    0.000    0.000    0.000 common.py:126(_classes_and_not_datetimelike)
#         4    0.000    0.000    0.000    0.000 range.py:316(step)
#         3    0.000    0.000    0.000    0.000 managers.py:536(nblocks)
#         7    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 range.py:299(stop)
#         1    0.000    0.000    0.000    0.000 <string>:2(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:260(__init__)
#         1    0.000    0.000    0.000    0.000 _json.py:1049(close)
#         3    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         7    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         3    0.000    0.000    0.000    0.000 managers.py:230(is_single_block)
#         4    0.000    0.000    0.000    0.000 {method 'isspace' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 <frozen _collections_abc>:262(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 common.py:1107(_maybe_memory_map)
#         4    0.000    0.000    0.000    0.000 function.py:64(__call__)
#         1    0.000    0.000    0.000    0.000 generic.py:1948(__iter__)
#         7    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 _validators.py:450(check_dtype_backend)
#         5    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#         4    0.000    0.000    0.000    0.000 _parser.py:1056(_could_be_tzname)
#         1    0.000    0.000    0.000    0.000 common.py:503(get_compression_method)
#         1    0.000    0.000    0.000    0.000 __init__.py:2337(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup_error}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 {method 'isdigit' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 range.py:213(_validate_dtype)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 generic.py:638(_info_axis)
#         1    0.000    0.000    0.000    0.000 {built-in method time.time}
#         2    0.000    0.000    0.000    0.000 __init__.py:1274(_reinsert_separating_lines)
#         3    0.000    0.000    0.000    0.000 frame.py:637(_constructor)
#         3    0.000    0.000    0.000    0.000 multiarray.py:669(result_type)
#         4    0.000    0.000    0.000    0.000 api.py:282(<listcomp>)
#         1    0.000    0.000    0.000    0.000 <frozen _collections_abc>:381(__subclasshook__)
#         3    0.000    0.000    0.000    0.000 {method 'pop' of 'set' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         1    0.000    0.000    0.000    0.000 threading.py:568(is_set)
#         3    0.000    0.000    0.000    0.000 {function FrozenList.__getitem__ at 0x000001F718E65940}
#         4    0.000    0.000    0.000    0.000 _parser.py:186(__iter__)
#         1    0.000    0.000    0.000    0.000 {built-in method from_iterable}
#         1    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 parse.py:108(_noop)
#         1    0.000    0.000    0.000    0.000 _json.py:1059(__iter__)
#
#
# {0: {(0, (1, 2))}}
# {0: {(0, ((1, 2), 3))}}
